# %% [markdown]
# File handling day-8

# %%
with open('info.text','w')as file:
    print(file.writelines,("Hello Satyam"))
# Out:
# <built-in method writelines of _io.TextIOWrapper object at 0x00000209CC502DC0> Hello Satyam

# %%
file=open("myfile.txt","w")
file.write("Hello ,This is my first file")
file.close()

# %%
file=open("myfile.txt","w")
file.write("Hello ,This is my Second file")
file.close()

# %%
file=open("new1file.txt","x")
file.write("File created successfully")
file.close()

# %%
file=open("new_file.txt","a")
file.write("This file is create using append mode ")
file.close()

# %%
with open("Datafile.txt","w") as file:
    file.write("Data is created using 'with' statement")

# %%
file = open("my_file.txt", "r")
print(file.read())
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 file = open("my_file.txt", "r")
#       2 print(file.read())
#       3 file.close()
#
# File c:\Users\Saytam\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_file.txt'

# %%
msg1='Pay  tax with smile...\n'
msg2='I tried but they wanted money!\n'
msg3='Don\'t feel bad....\n'
f=open('messages','w')
f.write(msg1)
f.write(msg2)
f.write(msg3)
f.close()
f=open('messages','r')
data=f.read()
print(data)
f.close()
# Out:
# Pay  tax with smile...
# I tried but they wanted money!
# Don't feel bad....

# %%
with open ("app.log",'w') as f:
    f.write("ERROR: Invalid input")

# %%
class stu:
    def stu(self):
        print("h")
s=stu()
s.stu()
# Out:
# h

# %%
class Animal:
    def __init__(self,name,species):
        self.name=name
        self.species=species
    def tell(self):
        print("i am animal")
class Dog(Animal):
    def speak(self):
        print("woof name:",self.name)
