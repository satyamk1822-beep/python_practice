# %% [markdown]
# 1-Ask the user to enter two numbers and display the results of addition,subtraction, multiplication, and division.

# %%
a=float(input("Enter frist no.:"))
b=float(input("Enter second no.:"))
print("Addition :",a+b)
print("Subtraction :",a-b)
print("Multiplication :",a*b)
print("Division :",a/b)
# Out:
# Addition : 5.0
# Subtraction : -1.0
# Multiplication : 6.0
# Division : 0.6666666666666666

# %% [markdown]
# 2-Take a number as a string, convert it into an integer and a float, then print the converted values and their types.

# %%
a=input("Entre a number:")
b=int(a)
c=float(a)
print(type(a),a)
print(type(b),b)
print(type(c),c)
# Out:
# <class 'str'> 3
# <class 'int'> 3
# <class 'float'> 3.0

# %% [markdown]
# 3-Input two numbers and print whether the first number is greater, smaller, or equal to the second.

# %%
a=int(input("Enter frist6 no. :"))
b=int(input("Enter second no. :"))
if a>b:
    print("a is greater ")
elif b>a:
    print("b is greatest")
else:
    print("both are equal ")
# Out:
# a is greater

# %% [markdown]
# 4-Take a Celsius temperature from the user, convert it to Fahrenheit, and print the result.

# %%
cel = float(input("Enter Celsius: "))
fahr = (cel * 9/5) + 32
print("Fahrenheit:", fahr)
# Out:
# Fahrenheit: 89.6

# %% [markdown]
# 5-Input a word and a character. Use the in operator to check whether the character exists inside the word.

# %%
a=(2,3,4,5)
print(3 in a)
# Out:
# True

# %% [markdown]
# 6-Create two variables (preferably lists).Check whether they refer to the same memory location using the "is" operator.

# %%
a=[2,3,4]
b=[2,3,4]
c=a
print(a is b)
print(c is a)
# Out:
# False
# True
