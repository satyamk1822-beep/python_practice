# %% [markdown]
# 1-Create a tuple of 6 fruits and print: first, last, and middle item.

# %%
fruit=('apple','mango','orange','graps','banana')
print(fruit[0],fruit[2],fruit[-1])
# Out:
# apple orange banana

# %% [markdown]
# 2-Create a tuple ( name , age , course ) and unpack values.

# %%
a=("Satyam",21,"BCA")
name,age,course=a
print(name,age,course)
# Out:
# Name ={name} Age={Age} Course={BCa}  Satyam 21 BCA

# %% [markdown]
# 3-Create two sets and print: union, intersection, and difference.

# %%
u={1,2}
a=u.union({1,2,3})
print(a)
print(a.intersection({2,3}))
print(a.difference({2}))
# Out:
# {1, 2, 3}
# {2, 3}
# {1, 3}

# %% [markdown]
# 4-Convert a list with repeated numbers to a set and print the set.

# %%
num=[1,2,1,1,2,2,3,3,4,4]
li=set(num)
print(li)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# 5-Create a dictionary and print keys and values separately

# %%
dict={"Name":"Satyam","age":21,"course":"BCA"}

for i in dict:
    print(i,dict[i])
# Out:
# Name Satyam
# age 21
# course BCA

# %% [markdown]
# 6-Add "grade" and update "marks" value.

# %% [markdown]
# 7-Print all key-value pairs using a loop.
