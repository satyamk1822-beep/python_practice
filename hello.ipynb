# %%
print("hello")
# Out:
# hello

# %% [markdown]
# 1️⃣ Welcome Message - Print your name, branch, college,and favourite language

# %%
print("Satyam,BCA,GOEL,Bhojpuri")
# Out:
# Satyam,BCA,GOEL,Bhojpuri

# %% [markdown]
# ️⃣ User Info Take name, age, city via input() and print

# %%
name=input("Enter Name")
age=int(input("Enter age"))
city=input("Enter city")
print(name,age,city)
# Out:
# Satyam  21 Ballia

# %% [markdown]
# 3️⃣ Basic Calculator Perform +, -, *, / with user input

# %%
a=int(input("Enter frist no"))
b=int(input("Enter second no"))

print(a+b,a-b,a*b,a/b)
# Out:
# 4 0 4 1.0

# %% [markdown]
# 4️⃣ Variables & Types Declare 5 variables & print their types using type()

# %%
a=2
b=3.4
c="bake bhari"
d=True
e=3+4j
print(type(a),type(b),type(c),type(d),type(e))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'> <class 'complex'>

# %% [markdown]
# 5️⃣ Swap Numbers Swap values using tuple method

# %%
a=2
b=3
a,b=b,a
print(a,b)
# Out:
# 3 2

# %% [markdown]
# 6️⃣ String Formatting Print a formatted introduction using f-string
